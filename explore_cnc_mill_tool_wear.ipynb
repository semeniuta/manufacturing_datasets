# %% [markdown]
# Dataset's page on Kaggle (with description):
# https://www.kaggle.com/shasun/tool-wear-detection-in-cnc-mill/

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
from glob import glob
from pprint import pprint

# %%
DATA_DIR = 'data/cnc_mill_tool_wear'

# %%
fnames_experiments = sorted(glob(os.path.join(DATA_DIR, 'experiment_*.csv')))

fnames_experiments
# Out:
# ['data/cnc_mill_tool_wear/experiment_01.csv',
#  'data/cnc_mill_tool_wear/experiment_02.csv',
#  'data/cnc_mill_tool_wear/experiment_03.csv',
#  'data/cnc_mill_tool_wear/experiment_04.csv',
#  'data/cnc_mill_tool_wear/experiment_05.csv',
#  'data/cnc_mill_tool_wear/experiment_06.csv',
#  'data/cnc_mill_tool_wear/experiment_07.csv',
#  'data/cnc_mill_tool_wear/experiment_08.csv',
#  'data/cnc_mill_tool_wear/experiment_09.csv',
#  'data/cnc_mill_tool_wear/experiment_10.csv',
#  'data/cnc_mill_tool_wear/experiment_11.csv',
#  'data/cnc_mill_tool_wear/experiment_12.csv',
#  'data/cnc_mill_tool_wear/experiment_13.csv',
#  'data/cnc_mill_tool_wear/experiment_14.csv',
#  'data/cnc_mill_tool_wear/experiment_15.csv',
#  'data/cnc_mill_tool_wear/experiment_16.csv',
#  'data/cnc_mill_tool_wear/experiment_17.csv',
#  'data/cnc_mill_tool_wear/experiment_18.csv']

# %%
fname_train = os.path.join(DATA_DIR, 'train.csv')

fname_train
# Out:
# 'data/cnc_mill_tool_wear/train.csv'

# %%
first_file = fnames_experiments[0]
print(first_file)
# Out:
# data/cnc_mill_tool_wear/experiment_01.csv

# %%
df = pd.read_csv(first_file)

# %%
df
# Out:
#       X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0                 198.0              0.000                   0.00
# 1                 198.0            -10.800                -350.00
# 2                 196.0            -17.800                  -6.25
# 3                 194.0            -18.000                   0.00
# 4                 193.0            -17.900                 -18.80
# ...                 ...                ...                    ...
# 1050              141.0              0.175                  87.50
# 1051              141.0             -0.150                 -87.50
# 1052              141.0             -0.175                 -87.50
# 1053              141.0              0.150                  87.50
# 1054              141.0              0.175                  93.70
#
#       X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0                  198.0                 0.0                0.000000
# ...

# %%
pprint(sorted(df.columns))
# Out:
# ['M1_CURRENT_FEEDRATE',
#  'M1_CURRENT_PROGRAM_NUMBER',
#  'M1_sequence_number',
#  'Machining_Process',
#  'S1_ActualAcceleration',
#  'S1_ActualPosition',
#  'S1_ActualVelocity',
#  'S1_CommandAcceleration',
#  'S1_CommandPosition',
#  'S1_CommandVelocity',
#  'S1_CurrentFeedback',
#  'S1_DCBusVoltage',
#  'S1_OutputCurrent',
#  'S1_OutputPower',
#  'S1_OutputVoltage',
#  'S1_SystemInertia',
#  'X1_ActualAcceleration',
#  'X1_ActualPosition',
#  'X1_ActualVelocity',
#  'X1_CommandAcceleration',
#  'X1_CommandPosition',
#  'X1_CommandVelocity',
#  'X1_CurrentFeedback',
#  'X1_DCBusVoltage',
#  'X1_OutputCurrent',
#  'X1_OutputPower',
#  'X1_OutputVoltage',
#  'Y1_ActualAcceleration',
#  'Y1_ActualPosition',
#  'Y1_ActualVelocity',
#  'Y1_CommandAcceleration',
#  'Y1_CommandPosition',
#  'Y1_CommandVelocity',
#  'Y1_CurrentFeedback',
#  'Y1_DCBusVoltage',
#  'Y1_OutputCurrent',
#  'Y1_OutputPower',
#  'Y1_OutputVoltage',
#  'Z1_ActualAcceleration',
#  'Z1_ActualPosition',
# ...
